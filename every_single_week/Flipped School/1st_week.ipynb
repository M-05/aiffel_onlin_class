# %% [markdown]
# # EDA의 기초
# EDA는 전처리 단계에서 정제된 데이터를 받아 분석하고 피처 엔지니어링(feature enginnering)으로 넘겨 주는 역할입니다만 전처리의 일부는 EDA를 진행해야 할 수 있고 피처 엔지니어링 역시 EDA와 혼재되어있기 때문에 실은 명확하게 구분되는 과정은 아닙니다.
#
# 이번 풀잎에서 전처리는 주로 이상치와 결측값 처리 등을 주로 살펴볼 예정이며 EDA의 기본이라고 할 수 있는 기초 통계량을 확인하는 것부터 데이터의 특징(feature)를 찾아내는 과정까지 함께 공부해보도록 하겠습니다.
#
# 여기서 기초 통계량이란 데이터의 가장 기본적인 특징인 평균, 분산, 편차 등을 일컷지만 경우에 따라선 다섯 수치 요약, 왜도, 첨도 등을 포함하기도 합니다.
#
# 본 수업에서는 Fundamental 9. 다양한 데이터 전처리 기법에서 소개된 캐글 Video Game Sales 데이터의 일부를 변형한 데이터를 사용합니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
ls
# Out:
#  1st_week.ipynb
#  2nd_week.ipynb
# '2] The mathematical building blocks of neural networks.ipynb'
#  class.csv
# 'import numpy[Numerical Python] as np.ipynb'
#  vgsales_lecture.csv
#  zoo.csv

# %%
df = pd.read_csv("vgsales_lecture.csv")

# %% [markdown]
# ## Unit 1. 데이터 살펴보기

# %% [markdown]
# 이번 풀잎에서는 판다스 시리즈 / 데이터프레임을 이용하도록 하겠습니다.
#
# 판다스는 여러가지 함수를 제공하며 데이터 조작 및 EDA를 빠르고 손쉽게 진행할 수 있도록 도와주는 도구입니다.
#
# 아래서는 몇가지 함수를 통해 살펴보도록 하겠습니다.

# %% [markdown]
# ### 방법 1. df.info()
#
# info 함수는 총 데이터 수와 데이터 타입에 대한 정보를 제공합니다.
#
# 아래에서 조금 더 살펴보도록 하겠습니다.

# %%
df.info()
# 16598 entries float64(5), int64(1), object(5) 11 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  object
#  4   Genre         16598 non-null  object
#  5   Publisher     16335 non-null  object
#  6   NA_Sales      12099 non-null  float64
#  7   EU_Sales      10870 non-null  float64
#  8   JP_Sales      6141 non-null   float64
#  9   Other_Sales   10123 non-null  float64
#  10  Global_Sales  16596 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Rank                0
# Name                0
# Platform            0
# Year              271
# Genre               0
# Publisher         263
# NA_Sales         4499
# EU_Sales         5728
# JP_Sales        10457
# Other_Sales      6475
# Global_Sales        2
# dtype: int64

# %% [markdown]
# ### 방법 2. df.head()
#
# 앞으로 주구장창 보게되실 head 함수는 데이터량이 많을때 앞의 몇개만 골라서 볼 수 있는 함수입니다.
#
# 반대로 뒤에서 뽑아오는 tail이란 함수도 있습니다.

# %%
df.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ### 방법 3. series.unique()
#
# unique 함수는 함수 이름처럼 중복값을 제하고 남은 것들만 보여줍니다.
#
# 시리즈에서 사용하는 함수로 데이터 프레임에선 nunique() 함수를 사용해줄 수 있지만 갯수만을 카운트해줍니다.

# %%
df.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           33
# Year               40
# Genre              14
# Publisher         577
# NA_Sales          408
# EU_Sales          304
# JP_Sales          243
# Other_Sales       156
# Global_Sales      623
# dtype: int64

# %%
df["Year"].unique()
# Out:
# array(['2006', '1985', '2008', '2009', '1996', '1989', '1984', '2005',
#        '1999', '2007', '2010', '2013', '2004', '1990', '1988', '2002',
#        '2001', '2011', '1998', '2015', '2012', '2014', '1992', '1997',
#        '1993', '1994', '1982', '2003', '1986', '2000', nan, '1995',
#        '2016', '1991', '1981', '1987', '1980', '1983', '2020',
#        'Adventure', '2017'], dtype=object)

# %%
df["Year"].nunique()
# Out:
# 40

# %%
df["Platform"].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '2007', '3DO', 'GG', '2010', 'PCFX'], dtype=object)

# %%
# 아래와 같은 오류가 발생하는 것은 당연한 일입니다.
# df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-84bc62f43960> in <module>()
# ----> 1 df.unique()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %% [markdown]
# ### 방법 4. df.describe()
#
# 마지막으로 describe는 요약 통계를 한 번에 보여줍니다.
#
# describe 역시 여러가지 파라미터가 있지만 해당 부분은 판다스 문서를 참조해주세요.

# %%
df.describe()
# Out:
#                Rank      NA_Sales      EU_Sales     JP_Sales   Other_Sales  \
# count  16598.000000  12099.000000  10870.000000  6141.000000  10123.000000
# mean    8300.605254      0.363084      0.223942     0.210210      0.078818
# std     4791.853933      0.937693      0.610455     0.480352      0.236416
# min        1.000000      0.010000      0.010000     0.010000      0.010000
# 25%     4151.250000      0.060000      0.020000     0.030000      0.010000
# 50%     8300.500000      0.140000      0.070000     0.070000      0.030000
# 75%    12449.750000      0.350000      0.200000     0.190000      0.070000
# max    16600.000000     41.490000     29.020000    10.220000     10.570000
#
#        Global_Sales
# count  16596.000000
# mean       0.537498
# std        1.555113
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %%
df["NA_Sales"].std()
# Out:
# 0.9376928421792661

# %%
df.quantile(q =0.5, axis= 0)
# Out:
# Rank            8300.50
# NA_Sales           0.14
# EU_Sales           0.07
# JP_Sales           0.07
# Other_Sales        0.03
# Global_Sales       0.17
# Name: 0.5, dtype: float64

# %%
df.quantile?

# %% [markdown]
# df.quantile(
#     q=0.5,
#     axis: 'Axis' = 0,
#     numeric_only: 'bool' = True,
#     interpolation: 'str' = 'linear',
# )

# %%
df.quantile()
# Out:
# Rank            8300.50
# NA_Sales           0.14
# EU_Sales           0.07
# JP_Sales           0.07
# Other_Sales        0.03
# Global_Sales       0.17
# Name: 0.5, dtype: float64

# %% [markdown]
# ### 조별학습 1
#
# 판다스 문서의 주소는 아래와 같습니다.
#
# https://pandas.pydata.org/docs/reference/index.html
#
# 우측 목록에서 dataframe 혹은 series을 열어보면 수많은 함수들이 있을 것입니다.
#
# ❗(조별학습)지금부터는 조별로 위의 describe 함수 결과값을 하나씩 어떤 코드를 통해 구현해낼 수 있을지 고민해봅시다.

# %% [markdown]
# ## Unit 2. 이상치와 결측치 탐색

# %% [markdown]
# 그럼 이번엔 이상치를 탐색해 보도록 하겠습니다.
#
# 일반적인 경우 값이 매우 크거나 매우 작은 경우를 의미하기 때문에 그래프를 통해, 혹은  z-score 등을 통해서 찾아내는 것이 일반적이지만 연도의 경우 값의 종류 자체가 많지 않기 때문에 한 번 데이터를 뽑아보겠습니다.

# %%
df["Year"].unique()
# Out:
# array(['2006', '1985', '2008', '2009', '1996', '1989', '1984', '2005',
#        '1999', '2007', '2010', '2013', '2004', '1990', '1988', '2002',
#        '2001', '2011', '1998', '2015', '2012', '2014', '1992', '1997',
#        '1993', '1994', '1982', '2003', '1986', '2000', nan, '1995',
#        '2016', '1991', '1981', '1987', '1980', '1983', '2020',
#        'Adventure', '2017'], dtype=object)

# %%
df[df["Year"] == "nan"]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df[df["Year"]=="Adventure"]
# Out:
#         Rank                                               Name Platform  \
# 11593  11595  Boku no Natsuyasumi 3: Hokkoku Hen: Chiisana B...     2007
# 13538  13540                                 B's-LOG Party??PSP     2010
#
#             Year                        Genre Publisher  NA_Sales  EU_Sales  \
# 11593  Adventure  Sony Computer Entertainment       NaN       NaN      0.08
# 13538  Adventure                 Idea Factory       NaN       NaN      0.04
#
#        JP_Sales  Other_Sales  Global_Sales
# 11593       NaN         0.08           NaN
# 13538       NaN         0.04           NaN

# %% [markdown]
# Platform에는 연도가, Year에는 장르가, 장르에는 플랫폼이 적혀있습니다.
#
# 전형적인 휴먼에러로군요. 자연상의 데이터도 아닌 정제된 데이터에도 오류(노이즈)가 존재합니다.
#
# 다행히 그 이외엔 특별히 이상치가 눈에 보이진 않습니다.
#
# 이상치는 간단하게 drop함수를 통해 지워버릴 수도 있지만 이번에는 비교적 간단한 에러였기 때문에 직접 수정하도록 하겠습니다.

# %%
df.iloc[[11593,13538], 2:4 +1]
# Out:
#       Platform       Year                        Genre
# 11593     2007  Adventure  Sony Computer Entertainment
# 13538     2010  Adventure                 Idea Factory

# %%
# 이 코드는 바로 적용해서 바꾸기 때문에 여러번 실행하면 계속 바뀌게 됩니다. 적용후에는 주석처리 해주세요

df.iloc[11593, [2, 3, 4]] = list(df.iloc[11593, [4, 2, 3]])
df.iloc[13538, [2, 3, 4]] = list(df.iloc[13538, [4, 2, 3]])

# %%
df.iloc[11593, [2, 3, 4]] = df.iloc[11593, [4, 2, 3]]
df.iloc[13538, [2, 3, 4]] = df.iloc[13538, [4, 2, 3]]

# %%
df.iloc[11593, [4, 2, 3]].shape
# Out:
# (3,)

# %%
list(df.iloc[11593, [4, 2, 3]]).shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_48/2891558689.py in <module>
# ----> 1 list(df.iloc[11593, [4, 2, 3]]).shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
df.iloc[[11593,13538], 2:4 +1]
# Out:
#                           Platform  Year      Genre
# 11593  Sony Computer Entertainment  2007  Adventure
# 13538                 Idea Factory  2010  Adventure

# %%
df.iloc[11593]
# Out:
# Rank                                                        11595
# Name            Boku no Natsuyasumi 3: Hokkoku Hen: Chiisana B...
# Platform                              Sony Computer Entertainment
# Year                                                         2007
# Genre                                                   Adventure
# Publisher                                                     NaN
# NA_Sales                                                      NaN
# EU_Sales                                                     0.08
# JP_Sales                                                      NaN
# Other_Sales                                                  0.08
# Global_Sales                                                  NaN
# Name: 11593, dtype: object

# %% [markdown]
# 그럼 계속해서 nan, 결측치에 대해서 살펴보도록 하겠습니다.

# %%
df[df[["Year"]].isnull().any(axis= 1)].sum()
# Out:
# Rank                                                      2375787
# Name            Madden NFL 2004FIFA Soccer 2004LEGO Batman: Th...
# Platform        PS2PS2WiiPS22600X360GBAWiiWiiWiiPCPS3PSWiiPSP2...
# Year                                                            0
# Genre           SportsSportsActionFightingShooterMiscAdventure...
# NA_Sales                                                    59.52
# EU_Sales                                                    25.01
# JP_Sales                                                     6.72
# Other_Sales                                                  8.74
# Global_Sales                                               100.08
# dtype: object

# %%
df[df[["Year"]].isnull().any(axis=1)].head()
# Out:
#      Rank                        Name  ... Other_Sales Global_Sales
# 179   180             Madden NFL 2004  ...        0.71         5.23
# 377   378            FIFA Soccer 2004  ...        0.51         3.49
# 431   432  LEGO Batman: The Videogame  ...        0.29         3.17
# 470   471  wwe Smackdown vs. Raw 2006  ...        0.41         3.00
# 607   608              Space Invaders  ...        0.03         2.53
#
# [5 rows x 11 columns]

# %% [markdown]
# 위키 백과에 따르면 가장 먼저 나오는 Madden NFL 2004는 2003년 Game Boy Advance, GameCube, Microsoft Windows, PlayStation, PlayStation 2, Xbox를 통해 발매되었다고 합니다.
#
# https://en.wikipedia.org/wiki/Madden_NFL_2004

# %%
df.loc[179, "Name"]
# Out:
# 'Madden NFL 2004'

# %%
df.iloc[179]
# Out:
# Rank                        180
# Name            Madden NFL 2004
# Platform                    PS2
# Year                        NaN
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   4.26
# EU_Sales                   0.26
# JP_Sales                   0.01
# Other_Sales                0.71
# Global_Sales               5.23
# Name: 179, dtype: object

# %%
df.iloc[179, 3] = 2003
df.iloc[179]
# Out:
# Rank                        180
# Name            Madden NFL 2004
# Platform                    PS2
# Year                       2003
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   4.26
# EU_Sales                   0.26
# JP_Sales                   0.01
# Other_Sales                0.71
# Global_Sales               5.23
# Name: 179, dtype: object

# %% [markdown]
# ### 조별학습 2
#
# 우리가 원하는대로 바뀌었습니다. 그런데 생각해보면 야구나 축구 게임 제목에 연도가 붙는 경우가 많은 것 같습니다.
#
# 마침 그 아래 항목을 보니 FIFA Soccer 2004의 경우도 2003년 발매가 되었습니다. 스포츠 게임 타이틀에 연도가 붙은 경우 해당 연도 -1을 적용하면 하나하나 찾아보지 않고 결측치를 채워넣을 수 있을 것 같습니다.
#
# ❗(조별학습)어떻게 하면 해당 결측치를 채워넣을 수 있을까요?
#
# 원본 데이터 프레임에 적용하기 전에 "Year" 컬럼이 NaN인 행만 뽑은 df_temp를 만들어 실습해봅시다.
#
# Hint. apply 함수를 이용해서 한 번에 처리 할 수도 있을 것 같습니다.

# %%
df[df[["Year"]].isnull().any(axis=1)]
# Out:
#         Rank                         Name Platform Year         Genre  \
# 179      180              Madden NFL 2004      PS2  NaN        Sports
# 377      378             FIFA Soccer 2004      PS2  NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii  NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2  NaN      Fighting
# 607      608               Space Invaders     2600  NaN       Shooter
# ...      ...                          ...      ...  ...           ...
# 16307  16310                Freaky Flyers       GC  NaN        Racing
# 16327  16330                    Inversion       PC  NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3  NaN     Adventure
# 16427  16430                 Virtua Quest       GC  NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS  NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 179                           Electronic Arts      4.26      0.26      0.01
# 377                           Electronic Arts      0.59      2.36      0.04
# 431    Warner Bros. Interactive Entertainment      1.86      1.02       NaN
# 470                                       NaN      1.57      1.02       NaN
# 607                                     Atari      2.36      0.14       NaN
# ...                                       ...       ...       ...       ...
# 16307                                     NaN      0.01       NaN       NaN
# 16327                      Namco Bandai Games      0.01       NaN       NaN
# 16366                                     NaN      0.01       NaN       NaN
# 16427                                     NaN      0.01       NaN       NaN
# 16493                                     NaN       NaN      0.01       NaN
#
#        Other_Sales  Global_Sales
# 179           0.71          5.23
# 377           0.51          3.49
# 431           0.29          3.17
# 470           0.41          3.00
# 607           0.03          2.53
# ...            ...           ...
# 16307          NaN          0.01
# 16327          NaN          0.01
# 16366          NaN          0.01
# 16427          NaN          0.01
# 16493          NaN          0.01
#
# [271 rows x 11 columns]

# %%
df[df["Genre"] == "Sports"]
# Out:
#         Rank                           Name Platform  Year   Genre  \
# 0          1                     Wii Sports      Wii  2006  Sports
# 3          4              Wii Sports Resort      Wii  2009  Sports
# 13        14                        Wii Fit      Wii  2007  Sports
# 14        15                   Wii Fit Plus      Wii  2009  Sports
# 77        78                        FIFA 16      PS4  2015  Sports
# ...      ...                            ...      ...   ...     ...
# 16576  16579              Rugby Challenge 3     XOne  2016  Sports
# 16578  16581  Outdoors Unleashed: Africa 3D      3DS  2011  Sports
# 16579  16582              PGA European Tour      N64  2000  Sports
# 16581  16584                      Fit & Fun      Wii  2011  Sports
# 16587  16590       Mezase!! Tsuri Master DS       DS  2009  Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                  Nintendo     41.49     29.02      3.77         8.46
# 3                  Nintendo     15.75     11.01      3.28         2.96
# 13                 Nintendo      8.94      8.03      3.60         2.15
# 14                 Nintendo      9.09      8.59      2.53         1.79
# 77          Electronic Arts      1.11      6.06      0.06         1.26
# ...                     ...       ...       ...       ...          ...
# 16576  Alternative Software       NaN      0.01       NaN          NaN
# 16578               Mastiff      0.01       NaN       NaN          NaN
# 16579            Infogrames      0.01       NaN       NaN          NaN
# 16581                   NaN       NaN      0.01       NaN          NaN
# 16587           Hudson Soft       NaN       NaN      0.01          NaN
#
#        Global_Sales
# 0             82.74
# 3             33.00
# 13            22.72
# 14            22.00
# 77             8.49
# ...             ...
# 16576          0.01
# 16578          0.01
# 16579          0.01
# 16581          0.01
# 16587          0.01
#
# [2346 rows x 11 columns]

# %%
df_temp = df[df[["Year"]].isnull().any(axis=1)][df["Genre"] == "Sports"]
df_temp
# Out:
#         Rank                                    Name Platform Year   Genre  \
# 179      180                         Madden NFL 2004      PS2  NaN  Sports
# 377      378                        FIFA Soccer 2004      PS2  NaN  Sports
# 1303    1305                          Triple Play 99       PS  NaN  Sports
# 2484    2486                           Madden NFL 07      PSP  NaN  Sports
# 2497    2499                      MLB SlugFest 20-03      PS2  NaN  Sports
# 2528    2530                Shaun White Snowboarding     X360  NaN  Sports
# 2586    2588          PES 2009: Pro Evolution Soccer      PSP  NaN  Sports
# 2776    2778                           Madden NFL 11      Wii  NaN  Sports
# 3421    3423                           Madden NFL 06     X360  NaN  Sports
# 3501    3503                         Madden NFL 2002       XB  NaN  Sports
# 3753    3755                       NBA Street Vol. 2       GC  NaN  Sports
# 3880    3882                           Fishing Derby     2600  NaN  Sports
# 4199    4201                 Tiger Woods PGA Tour 07      Wii  NaN  Sports
# 4536    4538                            NHL Slapshot      Wii  NaN  Sports
# 4797    4799                        NFL GameDay 2003      PS2  NaN  Sports
# 5162    5164                           NBA Live 2003       XB  NaN  Sports
# 5669    5671                  All-Star Baseball 2005      PS2  NaN  Sports
# 5901    5903                           NBA Live 2003       GC  NaN  Sports
# 6496    6498              Jonah Lomu Rugby Challenge      PS3  NaN  Sports
# 6647    6649                       College Hoops 2K6      PS2  NaN  Sports
# 6937    6939                Tony Hawk's Downhill Jam      Wii  NaN  Sports
# 6966    6968                      Big Beach Sports 2      Wii  NaN  Sports
# 7181    7183                            Move Fitness      PS3  NaN  Sports
# 7615    7617                              Famista 64      N64  NaN  Sports
# 8086    8088                             Backbreaker     X360  NaN  Sports
# 8204    8206                       NBA Starting Five      PS2  NaN  Sports
# 8313    8315                             Backbreaker      PS3  NaN  Sports
# 8760    8762                                Home Run     2600  NaN  Sports
# 8929    8931                  All-Star Baseball 2005       XB  NaN  Sports
# 9392    9394                         Transworld Surf       XB  NaN  Sports
# 9815    9817                            Street Hoops       GC  NaN  Sports
# 9868    9870               Major League Baseball 2K6      PSP  NaN  Sports
# 10494  10496  Atsumare! Power Pro Kun no DS Koushien       DS  NaN  Sports
# 11331  11333                      Get Fit with Mel B     X360  NaN  Sports
# 12915  12917                Mountain Bike Adrenaline      PS2  NaN  Sports
# 13733  13735                            NHL Hitz Pro       GC  NaN  Sports
# 14098  14100               Major League Baseball 2K8      PSP  NaN  Sports
# 15261  15264                            Mario Tennis      3DS  NaN  Sports
# 15579  15582              Cabela's Alaskan Adventure      PS2  NaN  Sports
# 15739  15742                   Football Manager 2007     X360  NaN  Sports
# 15865  15868       PDC World Championship Darts 2008       DS  NaN  Sports
# 16057  16060       PDC World Championship Darts 2008      PSP  NaN  Sports
#
#                           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 179                 Electronic Arts      4.26      0.26      0.01
# 377                 Electronic Arts      0.59      2.36      0.04
# 1303                            NaN      0.81      0.55       NaN
# 2484                            NaN      0.77      0.03       NaN
# 2497                            NaN      0.41      0.32       NaN
# 2528                        Ubisoft      0.48      0.26       NaN
# 2586   Konami Digital Entertainment      0.04      0.33      0.26
# 2776                            NaN      0.70       NaN       NaN
# 3421                Electronic Arts      0.54       NaN      0.01
# 3501                            NaN      0.53      0.02       NaN
# 3753                Electronic Arts      0.41      0.11       NaN
# 3880                     Activision      0.48      0.03       NaN
# 4199                Electronic Arts      0.43       NaN       NaN
# 4536                            NaN      0.40       NaN       NaN
# 4797                            NaN      0.20      0.15       NaN
# 5162                Electronic Arts      0.31      0.04       NaN
# 5669                            NaN      0.16      0.12       NaN
# 5901                Electronic Arts      0.23      0.06       NaN
# 6496   Home Entertainment Suppliers       NaN      0.20       NaN
# 6647                            NaN      0.12      0.10       NaN
# 6937                     Activision      0.21       NaN       NaN
# 6966                            THQ      0.09      0.12       NaN
# 7181    Sony Computer Entertainment       NaN      0.17       NaN
# 7615             Namco Bandai Games       NaN       NaN      0.17
# 8086                            NaN      0.17       NaN       NaN
# 8204                            NaN      0.09      0.07       NaN
# 8313                            NaN      0.16       NaN       NaN
# 8760                          Atari      0.14      0.01       NaN
# 8929                            NaN      0.11      0.03       NaN
# 9392                          Atari      0.10      0.03       NaN
# 9815                            NaN      0.09      0.02       NaN
# 9868                            NaN      0.11       NaN       NaN
# 10494                           NaN       NaN       NaN      0.10
# 11331              Black Bean Games       NaN      0.07       NaN
# 12915                           NaN      0.03      0.02       NaN
# 13733                           NaN      0.03      0.01       NaN
# 14098                           NaN      0.03       NaN       NaN
# 15261                           NaN       NaN       NaN      0.02
# 15579                           NaN      0.01      0.01       NaN
# 15739                          Sega       NaN      0.01       NaN
# 15865                           NaN      0.01       NaN       NaN
# 16057            Oxygen Interactive      0.01       NaN       NaN
#
#        Other_Sales  Global_Sales
# 179           0.71          5.23
# 377           0.51          3.49
# 1303          0.10          1.46
# 2484          0.04          0.83
# 2497          0.11          0.83
# 2528          0.08          0.82
# 2586          0.17          0.80
# 2776          0.05          0.74
# 3421          0.03          0.59
# 3501          0.03          0.58
# 3753          0.01          0.54
# 3880          0.01          0.51
# 4199          0.04          0.47
# 4536          0.02          0.43
# 4797          0.05          0.40
# 5162          0.01          0.36
# 5669          0.04          0.32
# 5901          0.01          0.30
# 6496          0.06          0.26
# 6647          0.03          0.25
# 6937          0.02          0.24
# 6966          0.03          0.23
# 7181          0.05          0.22
# 7615          0.03          0.20
# 8086          0.01          0.18
# 8204          0.02          0.18
# 8313          0.01          0.17
# 8760           NaN          0.15
# 8929          0.01          0.15
# 9392           NaN          0.13
# 9815           NaN          0.12
# 9868          0.01          0.12
# 10494          NaN          0.10
# 11331         0.01          0.08
# 12915         0.01          0.05
# 13733          NaN          0.04
# 14098          NaN          0.03
# 15261          NaN          0.02
# 15579          NaN          0.02
# 15739          NaN          0.02
# 15865          NaN          0.02
# 16057          NaN          0.01

# %%
df_temp = df[df["Genre"] == "Sports"].iloc[:50]
df_temp
# Out:
#      Rank                                            Name Platform  Year  \
# 0       1                                      Wii Sports      Wii  2006
# 3       4                               Wii Sports Resort      Wii  2009
# 13     14                                         Wii Fit      Wii  2007
# 14     15                                    Wii Fit Plus      Wii  2009
# 77     78                                         FIFA 16      PS4  2015
# 85     86              Mario & Sonic at the Olympic Games      Wii  2007
# 112   113                                         FIFA 14      PS3  2013
# 117   118                                   Zumba Fitness      Wii  2010
# 121   122                                         FIFA 12      PS3  2011
# 124   125                                         FIFA 15      PS4  2014
# 139   140                                   Kinect Sports     X360  2010
# 179   180                                 Madden NFL 2004      PS2   NaN
# 189   190              Mario & Sonic at the Olympic Games       DS  2008
# 199   200                                  FIFA Soccer 11      PS3  2010
# 202   203                          Tony Hawk's Pro Skater       PS  1999
# 211   212                                   Madden NFL 06      PS2  2005
# 219   220                                         FIFA 15      PS3  2014
# 221   222                                         FIFA 17      PS4  2016
# 225   226                        Tony Hawk's Pro Skater 2       PS  2000
# 233   234       Mario & Sonic at the Olympic Winter Games      Wii  2009
# 238   239                                 Madden NFL 2005      PS2  2004
# 240   241                                   Madden NFL 07      PS2  2006
# 248   249                        Tony Hawk's Pro Skater 3      PS2  2001
# 249   250       Winning Eleven: Pro Evolution Soccer 2007      PS2  2006
# 256   257                                         FIFA 14     X360  2013
# 269   270                                  FIFA Soccer 06      PS2  2005
# 275   276                                         FIFA 12     X360  2011
# 279   280                                 Madden NFL 2003      PS2  2002
# 283   284                                  FIFA Soccer 07      PS2  2006
# 292   293                   World Soccer Winning Eleven 9      PS2  2005
# 298   299                                            Golf      NES  1984
# 303   304                                EA Sports Active      Wii  2009
# 306   307                         Tony Hawk's Underground      PS2  2003
# 313   314                                Sports Champions      PS3  2010
# 314   315                                        NBA 2K16      PS4  2015
# 315   316     World Soccer Winning Eleven 8 International      PS2  2004
# 323   324  Mario & Sonic at the London 2012 Olympic Games      Wii  2011
# 334   335                                FIFA Soccer 2005      PS2  2004
# 339   340                        Tony Hawk's Pro Skater 4      PS2  2002
# 347   348                                  FIFA Soccer 10      PS3  2009
# 348   349                       Pro Evolution Soccer 2008      PS2  2007
# 366   367                                  FIFA Soccer 11     X360  2010
# 370   371       Mario & Sonic at the Olympic Winter Games       DS  2009
# 377   378                                FIFA Soccer 2004      PS2   NaN
# 392   393                                FIFA Soccer 2003      PS2  2002
# 416   417                                         FIFA 16     XOne  2015
# 418   419                                   Madden NFL 16      PS4  2015
# 421   422                                        Baseball      NES  1983
# 440   441                                  FIFA Soccer 08      PS2  2007
# 449   450                                         FIFA 15     X360  2014
#
#       Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0    Sports                      Nintendo     41.49     29.02      3.77
# 3    Sports                      Nintendo     15.75     11.01      3.28
# 13   Sports                      Nintendo      8.94      8.03      3.60
# 14   Sports                      Nintendo      9.09      8.59      2.53
# 77   Sports               Electronic Arts      1.11      6.06      0.06
# 85   Sports                          Sega      2.58      3.90      0.66
# 112  Sports               Electronic Arts      0.78      4.32      0.07
# 117  Sports                     505 Games      3.50      2.64       NaN
# 121  Sports               Electronic Arts      0.84      4.32      0.11
# 124  Sports               Electronic Arts      0.79      4.29      0.05
# 139  Sports        Microsoft Game Studios      3.92      1.78      0.03
# 179  Sports               Electronic Arts      4.26      0.26      0.01
# 189  Sports                          Sega      1.64      2.48      0.44
# 199  Sports               Electronic Arts      0.60      3.29      0.06
# 202  Sports                    Activision      3.42      1.38      0.02
# 211  Sports               Electronic Arts      3.98      0.26      0.01
# 219  Sports               Electronic Arts      0.57      3.14      0.04
# 221  Sports               Electronic Arts      0.28      3.75      0.06
# 225  Sports                    Activision      3.05      1.41      0.02
# 233  Sports                          Sega      1.89      1.99      0.22
# 238  Sports               Electronic Arts      4.18      0.26      0.01
# 240  Sports               Electronic Arts      3.63      0.24      0.01
# 248  Sports                    Activision      2.66      1.29      0.01
# 249  Sports  Konami Digital Entertainment      0.10      2.39      1.05
# 256  Sports               Electronic Arts      0.92      2.93      0.01
# 269  Sports               Electronic Arts      0.78      2.55      0.04
# 275  Sports               Electronic Arts      0.84      2.79      0.02
# 279  Sports               Electronic Arts      3.36      0.21      0.01
# 283  Sports               Electronic Arts      0.71      2.48      0.03
# 292  Sports  Konami Digital Entertainment      0.12      2.26      0.90
# 298  Sports                      Nintendo      1.22      0.28      2.46
# 303  Sports               Electronic Arts      2.10      1.36      0.06
# 306  Sports                    Activision      2.29      1.17      0.01
# 313  Sports   Sony Computer Entertainment      2.12      1.14      0.10
# 314  Sports          Take-Two Interactive      2.48      0.65      0.03
# 315  Sports  Konami Digital Entertainment      0.16      1.89      1.12
# 323  Sports                          Sega      1.14      1.91      0.27
# 334  Sports               Electronic Arts      0.58      2.48      0.04
# 339  Sports                    Activision      2.13      1.18      0.01
# 347  Sports               Electronic Arts      0.60      2.46      0.05
# 348  Sports  Konami Digital Entertainment      0.05       NaN      0.64
# 366  Sports               Electronic Arts      0.71      2.40      0.02
# 370  Sports                          Sega      1.22      1.66      0.27
# 377  Sports               Electronic Arts      0.59      2.36      0.04
# 392  Sports               Electronic Arts      0.46      2.28      0.05
# 416  Sports               Electronic Arts      0.88      2.11       NaN
# 418  Sports               Electronic Arts      2.33      0.30       NaN
# 421  Sports                      Nintendo      0.73      0.10      2.35
# 440  Sports               Electronic Arts      0.68       NaN       NaN
# 449  Sports               Electronic Arts      0.78      2.02       NaN
#
#      Other_Sales  Global_Sales
# 0           8.46         82.74
# 3           2.96         33.00
# 13          2.15         22.72
# 14          1.79         22.00
# 77          1.26          8.49
# 85          0.91          8.06
# 112         1.73          6.90
# 117         0.67          6.81
# 121         1.42          6.69
# 124         1.47          6.59
# 139         0.51          6.24
# 179         0.71          5.23
# 189         0.58          5.14
# 199         1.13          5.08
# 202         0.20          5.02
# 211         0.66          4.91
# 219         1.07          4.82
# 221         0.69          4.77
# 225         0.20          4.68
# 233         0.48          4.58
# 238         0.08          4.53
# 240         0.61          4.49
# 248         0.46          4.41
# 249         0.86          4.39
# 256         0.46          4.31
# 269         0.84          4.21
# 275         0.53          4.19
# 279         0.56          4.14
# 283         0.89          4.11
# 292         0.77          4.06
# 298         0.04          4.01
# 303         0.40          3.92
# 306         0.42          3.90
# 313         0.51          3.87
# 314         0.69          3.85
# 315         0.68          3.85
# 323         0.46          3.78
# 334         0.59          3.70
# 339         0.35          3.67
# 347         0.52          3.63
# 348         2.93          3.63
# 366         0.40          3.53
# 370         0.38          3.52
# 377         0.51          3.49
# 392         0.61          3.40
# 416         0.23          3.23
# 418         0.59          3.22
# 421         0.02          3.20
# 440         2.46          3.14
# 449         0.30          3.11

# %%
# Pandas 사용이 낯설다면 좀 더 작은 데이터를 가지고 다뤄봐도 좋을 것입니다. 아래 코드는 Sports 장르만을 골라내는 코드입니다.

# 결측치만 모아서 보기
# df_temp = df[df[["Year"]].isnull().any(axis=1)][df["Genre"] == "Sports"]

# 50개만 사용해보기
# df_temp = df[df["Genre"] == "Sports"].iloc[:50]

df_temp = df[df["Genre"] == "Sports"]
df_temp.head()
# Out:
#     Rank               Name Platform  Year   Genre        Publisher  NA_Sales  \
# 0      1         Wii Sports      Wii  2006  Sports         Nintendo     41.49
# 3      4  Wii Sports Resort      Wii  2009  Sports         Nintendo     15.75
# 13    14            Wii Fit      Wii  2007  Sports         Nintendo      8.94
# 14    15       Wii Fit Plus      Wii  2009  Sports         Nintendo      9.09
# 77    78            FIFA 16      PS4  2015  Sports  Electronic Arts      1.11
#
#     EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      29.02      3.77         8.46         82.74
# 3      11.01      3.28         2.96         33.00
# 13      8.03      3.60         2.15         22.72
# 14      8.59      2.53         1.79         22.00
# 77      6.06      0.06         1.26          8.49

# %% [markdown]
# ### Hint(반드시 토의 후에 열어보세요)

# %%
# Hint

def year_function(row):
    if row[4] == "Sports":
        text = row[1].split()[-1]
        if text.isdigit() and (1960 <= int(text) <= 2022):
            return str(int(text) - 1)
        else:
            return row[3]
    else:
        return row[3]

df_temp["Year"] = df_temp.apply(year_function, axis = 1)

# %%
df_temp["Year"]
# Out:
# 0        2006
# 3        2009
# 13       2007
# 14       2009
# 77       2015
#          ...
# 16576    2016
# 16578    2011
# 16579    2000
# 16581    2011
# 16587    2009
# Name: Year, Length: 2346, dtype: object

# %%
df_temp["Year"]
# Out:
# 0        2006
# 3        2009
# 13       2007
# 14       2009
# 77       2015
#          ...
# 16576    2016
# 16578    2011
# 16579    2000
# 16581    2011
# 16587    2009
# Name: Year, Length: 2346, dtype: object

# %%
df_temp.head()
# Out:
#     Rank               Name Platform  ... JP_Sales Other_Sales Global_Sales
# 0      1         Wii Sports      Wii  ...     3.77        8.46        82.74
# 3      4  Wii Sports Resort      Wii  ...     3.28        2.96        33.00
# 13    14            Wii Fit      Wii  ...     3.60        2.15        22.72
# 14    15       Wii Fit Plus      Wii  ...     2.53        1.79        22.00
# 77    78            FIFA 16      PS4  ...     0.06        1.26         8.49
#
# [5 rows x 11 columns]

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2346 entries, 0 to 16587
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2346 non-null   int64
#  1   Name          2346 non-null   object
#  2   Platform      2346 non-null   object
#  3   Year          2315 non-null   object
#  4   Genre         2346 non-null   object
#  5   Publisher     2343 non-null   object
#  6   NA_Sales      1852 non-null   float64
#  7   EU_Sales      1573 non-null   float64
#  8   JP_Sales      600 non-null    float64
#  9   Other_Sales   1588 non-null   float64
#  10  Global_Sales  2346 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 219.9+ KB

# %% [markdown]
# 제 코드대로라면 10개의 "Year"값이 추가될겁니다!

# %% [markdown]
# ### 조별학습 3
#
# 다들 잘 해내셨으리라 생각합니다!
#
# 저 같은 경우 Triple Play 99처럼 맨 뒤 두글자만 표기하는 부분을 빠뜨렸군요!
#
# 그 외에도 20-03 이라던가 2K8 같이 생각지도 못한 표기들이 있었습니다.
#
# 다들 저보다 더 많은 경우에 대해서 고민해보셨으리라 기대합니다.
#
# 만일 연도가 없는 경우는 어떻게 할까요?
#
# 실은 제목을 통해서 찾아내는 것 보다 더 확실한 방법이 있습니다.
#
# 눈치채신 분들도 계시겠지만 이 데이터는 같은 게임이라도 발매된 플랫폼에 따라서 통계가 따로 잡혀있습니다. 운이 좋다면 다른 플랫폼에서 발매된 같은 게임의 통계자료에서 유의미한 자료를 찾아낼지도 모릅니다.
#
# ❗(조별학습)"Year" 컬럼이 빈 데이터 중 다른 플랫폼에서 발매된 데이터에 "Year"값이 있을 경우 이 값으로 결측치를 채워봅시다.

# %% [markdown]
# ### Hint(반드시 토의 후에 열어보세요)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.columns[1], df.columns[3]
# Out:
# ('Name', 'Year')

# %%
df_sorted = df.sort_values(by = [df.columns[1], df.columns[3]], ascending = False, na_position = "first")
df_sorted.head()
# Out:
#         Rank                          Name Platform  Year     Genre  \
# 9135    9137  ¡Shin Chan Flipa en colores!       DS  2007  Platform
# 470      471    wwe Smackdown vs. Raw 2006      PS2   NaN  Fighting
# 7835    7837  uDraw Studio: Instant Artist      Wii  2011      Misc
# 15523  15526  uDraw Studio: Instant Artist     X360  2011      Misc
# 627      628                  uDraw Studio      Wii  2010      Misc
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 9135   505 Games       NaN       NaN      0.14          NaN          0.14
# 470          NaN      1.57      1.02       NaN         0.41          3.00
# 7835         THQ      0.08      0.09       NaN         0.02          0.19
# 15523        THQ      0.01      0.01       NaN          NaN          0.02
# 627          THQ      1.67      0.58       NaN         0.20          2.46

# %% [markdown]
# 위 목록에선 보이지 않지만 na_position 인자를 first(default는 last)로 주게 되면 Nan 값을 제일 위로 올려줍니다. 저는 이 성질을 이용해 Null 값을 찾도록 하겠습니다.

# %%
df_sorted[df_sorted["Name"] == "Madden NFL 07"]
# Out:
#         Rank           Name Platform  ... JP_Sales Other_Sales Global_Sales
# 2484    2486  Madden NFL 07      PSP  ...      NaN        0.04         0.83
# 240      241  Madden NFL 07      PS2  ...     0.01        0.61         4.49
# 964      966  Madden NFL 07     X360  ...     0.01        0.13         1.80
# 2037    2039  Madden NFL 07       XB  ...      NaN        0.03         1.02
# 3246    3248  Madden NFL 07       GC  ...      NaN        0.02         0.62
# 3862    3864  Madden NFL 07      PS3  ...     0.01        0.04         0.52
# 3975    3977  Madden NFL 07      Wii  ...      NaN        0.04         0.50
# 7277    7279  Madden NFL 07       DS  ...      NaN        0.02         0.22
# 14814  14817  Madden NFL 07      GBA  ...      NaN         NaN         0.03
#
# [9 rows x 11 columns]

# %%
def general_year_function(row):
    if str(row[3]) == "nan":
        text = str(df_sorted[df_sorted["Name"] == row[1]].iloc[-1][3])
        if text.isdigit():
            return df_sorted[df_sorted["Name"] == row[1]].iloc[-1][3]
    else:
        return row[3]

# %%
df_sorted["Year"] = df_sorted.apply(general_year_function, axis = 1)
df_sorted[df_sorted["Name"] == "Madden NFL 07"]
# Out:
#         Rank           Name Platform  Year   Genre        Publisher  NA_Sales  \
# 2484    2486  Madden NFL 07      PSP  2006  Sports              NaN      0.77
# 240      241  Madden NFL 07      PS2  2006  Sports  Electronic Arts      3.63
# 964      966  Madden NFL 07     X360  2006  Sports  Electronic Arts      1.66
# 2037    2039  Madden NFL 07       XB  2006  Sports  Electronic Arts      0.97
# 3246    3248  Madden NFL 07       GC  2006  Sports  Electronic Arts      0.48
# 3862    3864  Madden NFL 07      PS3  2006  Sports  Electronic Arts      0.47
# 3975    3977  Madden NFL 07      Wii  2006  Sports  Electronic Arts      0.46
# 7277    7279  Madden NFL 07       DS  2006  Sports  Electronic Arts      0.20
# 14814  14817  Madden NFL 07      GBA  2006  Sports  Electronic Arts      0.02
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 2484       0.03       NaN         0.04          0.83
# 240        0.24      0.01         0.61          4.49
# 964         NaN      0.01         0.13          1.80
# 2037       0.03       NaN         0.03          1.02
# 3246       0.13       NaN         0.02          0.62
# 3862        NaN      0.01         0.04          0.52
# 3975        NaN       NaN         0.04          0.50
# 7277        NaN       NaN         0.02          0.22
# 14814      0.01       NaN          NaN          0.03

# %%
df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 9135 to 4754
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16451 non-null  object
#  4   Genre         16598 non-null  object
#  5   Publisher     16538 non-null  object
#  6   NA_Sales      12099 non-null  float64
#  7   EU_Sales      10870 non-null  float64
#  8   JP_Sales      6141 non-null   float64
#  9   Other_Sales   10123 non-null  float64
#  10  Global_Sales  16596 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# 내친김에 아까 만들어둔 year_function도 적용해봅시다.
#
# 단, 이미 처리된 데이터가 있기 때문에 처음에 했던 것과 달리 큰 효과는 없을 수 있습니다.

# %%
df_sorted["Year"] = df_sorted.apply(year_function, axis = 1)

# %%
df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 9135 to 4754
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16455 non-null  object
#  4   Genre         16598 non-null  object
#  5   Publisher     16335 non-null  object
#  6   NA_Sales      12099 non-null  float64
#  7   EU_Sales      10870 non-null  float64
#  8   JP_Sales      6141 non-null   float64
#  9   Other_Sales   10123 non-null  float64
#  10  Global_Sales  16596 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# 여러분의 결과물은 어떠신가요? 짧은 시간에 만든 것 치고는 제법 잘 채워진 것 같네요.
#
# 저는 아래 코드를 통해 원본 데이터에 적용해 두겠습니다.

# %%
df = df_sorted.sort_index(ascending = False)
df.head()
# Out:
#         Rank                                              Name Platform  Year  \
# 16597  16600                                  Spirits & Spells      GBA  2003
# 16596  16599                                        Know How 2       DS  2010
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
#
#           Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 16597  Platform     Wanadoo      0.01       NaN       NaN          NaN
# 16596    Puzzle    7G//AMES       NaN      0.01       NaN          NaN
# 16595    Racing  Activision       NaN       NaN       NaN          NaN
# 16594   Shooter  Infogrames      0.01       NaN       NaN          NaN
# 16593  Platform       Kemco      0.01       NaN       NaN          NaN
#
#        Global_Sales
# 16597          0.01
# 16596          0.01
# 16595          0.01
# 16594          0.01
# 16593          0.01

# %% [markdown]
# ### 조별 학습 4
#
# 남은 "Year" 컬럼은 어떻게 채울 수 있을까요?
#
# 이제 남은 수가 많지 않기 때문에 일일히 검색할 수도 있겠지만 10만개, 100만개짜리 데이터를 다룬다고 생각하고 방법을 논의해 봅시다.

# %% [markdown]
# ## Unit 3. 판매량을 채워보자!

# %% [markdown]
# 사실 어떻게 보면 연도에 있던 결측치는 큰 문제가 아니었을지도 모릅니다. 수도 적고 범위 역시 좁았기 때문이죠.
#
# 이번 유닛에서는 판매량에 있는 수많은 결측치를 채워보도록 하겠습니다.
#
# 그 중에서도 가장 일반적이면서도 많이 사용하는 방법들에 대해서 살펴보도록 하겠습니다.

# %% [markdown]
# ### 방법 1. pd.drop()
# 단순히 행 혹은 열을 제거하는 방법입니다.
#
# 예를 들어서 JP_sales의 경우 절반 이상이 결측치(본래는 0으로 기록)으로 비디오 게임이 일본에서 갖는 인기를 생각해볼때 6000여개의 데이터는 조금 이상합니다.
#
# 이런 경우 JP_sales 데이터 자체의 신뢰도가 낮기 때문에 아예 배제하는 것을 고려해볼 수 있습니다.

# %%
df.drop?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16328 non-null  object
#  4   Genre         16598 non-null  object
#  5   Publisher     16538 non-null  object
#  6   NA_Sales      12099 non-null  float64
#  7   EU_Sales      10870 non-null  float64
#  8   JP_Sales      6141 non-null   float64
#  9   Other_Sales   10123 non-null  float64
#  10  Global_Sales  16596 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# 이렇게 데이터에 결측치가 너무 많은 경우 JP_Sales 컬럼 자체를 제거하는 것도 고려해볼만 할 것 같습니다.

# %%
# inplace = False(default값)일 경우 원본에 적용되지 않기 때문에 아래 코드를 적용하기 위해서 주석과 같이 작성해야합니다.

# df = df.drop(columns = "JP_Sales", axis = 1)

df.drop(columns = "JP_Sales", axis = 1)
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 10 columns]

# %% [markdown]
# 이 방법을 사용하니 Global_Sales의 값을 수정할 필요가 있어보입니다.
#
# 하지만 그 전에 16595번이 제 눈에 띄는군요.(Global_Sales의 값을 수정하는 것은 숙제로 남겨두겠습니다.)
#
# NA, EU, 기타 지역에서 판매된 데이터가 없는데 global만? 아마도 일본에서만 팔렸던 데이터가 삭제되면서 문제가 된 모양입니다.
#
# global 판매량이 너무 낮은 경우 결측치도 너무 많고 데이터에 의미도 적을 것 같다는 생각이 드는군요. 어느정도 판매가 된 게임만을 골라보겠습니다.
#
# 다만 이 경우는 굳이 drop을 사용하지 않아도 괜찮습니다만 조금 복잡한 경우 여러번의 drop을 통해 원하는 결과만을 남기는 방법도 좋습니다.

# %%
df[df["Global_Sales"] >= 1]
# Out:
#       Rank                      Name  ... Other_Sales Global_Sales
# 0        1                Wii Sports  ...        8.46        82.74
# 1        2         Super Mario Bros.  ...        0.77        40.24
# 2        3            Mario Kart Wii  ...        3.31        35.82
# 3        4         Wii Sports Resort  ...        2.96        33.00
# 4        5  Pokemon Red/Pokemon Blue  ...        1.00        31.37
# ...    ...                       ...  ...         ...          ...
# 2076  2078          Wheel of Fortune  ...        0.06         1.00
# 2077  2079           Disney Infinity  ...        0.16         1.00
# 2078  2080                Dark Souls  ...        0.08         1.00
# 2079  2081        Puzzler Collection  ...        0.04         1.00
# 2080  2082       Jampack Winter 2000  ...        0.07         1.00
#
# [2081 rows x 11 columns]

# %% [markdown]
# ### 방법 2. df.dropna()
#
# dropna는 결측치를 기준으로 행이나 열을 삭제하는 방법입니다.
# 결측치가 포함되어있으면 삭제할 수도 있고 혹은 조건등을 다는 방법도 있습니다.
#
# dropna의 경우 많이 사용하기 때문에 파라미터에 대해서 간단하게 짚고 넘어가겠습니다.
#
# ### axis(default 값은 0입니다)
# >0, or 'index' : 결측값이 있는 행(가로)을 제거합니다.
# >
# >1, or 'columns' : 결측값이 있는 열(세로)을 제거합니다.
#
# ### how(default 값은 'any'입니다)
# >'any' : 결측치가 하나라도 있으면 해당 열/행을 제거합니다.
# >
# >'all' : 모든 항목이 결측치일때 해당 열/행을 제거합니다.
#
# ### threshint
# > int : 행/열 중 value가 있는 칸의 갯수가 int개 미만인 행/열을 제거합니다.
#
# ### subset
# > colomns or lows : 선택한 행/열들에 한해서 위 조건들을 적용합니다.

# %%
df.fillna?

# %%
# default 값인 axis = 0, how = 'any'

df.dropna()
# Out:
#         Rank                         Name  ... Other_Sales Global_Sales
# 0          1                   Wii Sports  ...        8.46        82.74
# 1          2            Super Mario Bros.  ...        0.77        40.24
# 2          3               Mario Kart Wii  ...        3.31        35.82
# 3          4            Wii Sports Resort  ...        2.96        33.00
# 4          5     Pokemon Red/Pokemon Blue  ...        1.00        31.37
# ...      ...                          ...  ...         ...          ...
# 11896  11898                Grand Kingdom  ...        0.01         0.07
# 12012  12014  Guilty Gear Xrd -Revelator-  ...        0.01         0.07
# 12488  12490     Odin Sphere: Leifthrasir  ...        0.01         0.06
# 13000  13002             Natural Doctrine  ...        0.01         0.05
# 13281  13283         Smash Court Tennis 3  ...        0.01         0.05
#
# [2366 rows x 11 columns]

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2366 entries, 0 to 13281
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2366 non-null   int64
#  1   Name          2366 non-null   object
#  2   Platform      2366 non-null   object
#  3   Year          2366 non-null   object
#  4   Genre         2366 non-null   object
#  5   Publisher     2366 non-null   object
#  6   NA_Sales      2366 non-null   float64
#  7   EU_Sales      2366 non-null   float64
#  8   JP_Sales      2366 non-null   float64
#  9   Other_Sales   2366 non-null   float64
#  10  Global_Sales  2366 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 221.8+ KB

# %% [markdown]
# 결측치가 하나도 없는 데이터 셋을 만들어냈습니다만 너무 많은 데이터가 잘린 것 같습니다.
#
# 이번엔 적당한 조건을 달아보도록 하겠습니다.

# %%
df.dropna(thresh = 3, subset = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"])
# Out:
#         Rank                             Name  ... Other_Sales Global_Sales
# 0          1                       Wii Sports  ...        8.46        82.74
# 1          2                Super Mario Bros.  ...        0.77        40.24
# 2          3                   Mario Kart Wii  ...        3.31        35.82
# 3          4                Wii Sports Resort  ...        2.96        33.00
# 4          5         Pokemon Red/Pokemon Blue  ...        1.00        31.37
# ...      ...                              ...  ...         ...          ...
# 14183  14185            MX vs. ATV Supercross  ...        0.01         0.03
# 14185  14187       Sacra Terra: Angelic Night  ...        0.01         0.03
# 14267  14270  Mystery Case Files: Ravenhearst  ...        0.01         0.03
# 14299  14302                       Men of War  ...        0.01         0.03
# 14301  14304  Metroid Prime: Federation Force  ...         NaN         0.03
#
# [8291 rows x 11 columns]

# %% [markdown]
# 이 경우 작은 단위에서 숫자가 안 맞는 것이 거슬리는군요.
#
# 이전에 했던 방법을 응용해 보겠습니다.

# %%
df.dropna(thresh = 3, subset = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"])[df["Global_Sales"] >= 1]
# Out:
#       Rank                      Name  ... Other_Sales Global_Sales
# 0        1                Wii Sports  ...        8.46        82.74
# 1        2         Super Mario Bros.  ...        0.77        40.24
# 2        3            Mario Kart Wii  ...        3.31        35.82
# 3        4         Wii Sports Resort  ...        2.96        33.00
# 4        5  Pokemon Red/Pokemon Blue  ...        1.00        31.37
# ...    ...                       ...  ...         ...          ...
# 2076  2078          Wheel of Fortune  ...        0.06         1.00
# 2077  2079           Disney Infinity  ...        0.16         1.00
# 2078  2080                Dark Souls  ...        0.08         1.00
# 2079  2081        Puzzler Collection  ...        0.04         1.00
# 2080  2082       Jampack Winter 2000  ...        0.07         1.00
#
# [1971 rows x 11 columns]

# %% [markdown]
# ### 방법 3. df.fillna()
#
# 결측치를 버리자니 데이터가 조금밖에 남지 않고 남겨두자니 눈에 가시로군요.
#
# 그렇다면 채우는 것은 어떨까요?
#
# fillna는 결측치를 채우는 방법 중 가장 쉬운 방법 중 하나입니다.
#
# 제 생각엔 퍼블리셔는 종류도 너무 많은데다 딱히 중요할 것 같지 않네요. 퍼블리셔에 있는 결측치는 Unknown으로 채우겠습니다.
#
# 또 판매량 데이터를 보니 주로 적게 팔린 경우에 결측치가 많다는 것은 혹시 아예 안 팔린 것은 아닐까요? 판매량의 결측치는 0으로 주도록 하겠습니다.

# %%
value = {"Publisher" : "Unknown", "NA_Sales" : 0, "EU_Sales" : 0, "JP_Sales" : 0, "Other_Sales" : 0}
df.fillna(value = value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6eaa8f1dcb3> in <module>()
# ----> 1 df.fillna(value = value)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### 조별학습 5
#
# 이처럼 결측치에 문자나 숫자를 정해서 집어넣어줄 수 있습니다.
#
# 당연히 그 숫자는 데이터의 평균값과 같은 통계값에서 가져올 수도 있겠죠.
#
# 혹은 method 파라미터에 'backfill'이나 'ffill' 등의 파라미터를 주면 다음에 나오는 첫번째 유효값으로 채우거나 이전에 나온 마지막 유효값으로 채울 수도 있습니다.
#
# 다만 이 방법은 이 데이터 셋에선 크게 유용해보이지 않는데 여러분들은 어떻게 생각하시나요? 잠시 생각해봅시다.
#
# ❗(생각해보기) 여기에도 써볼만 할까요? 그 이유는 무엇인가요?
# 혹은 별로일 것 같나요? 그렇다면 어떤 데이터에서 쓸만할까요?
